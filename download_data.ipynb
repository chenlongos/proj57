# %% [markdown]
# # 下载模型和数据
#
# 从 HuggingFace 下载预训练模型和数据集。

# %%
# !pip install -q huggingface_hub

from huggingface_hub import snapshot_download

# 下载模型
print("下载模型...")
snapshot_download(
    "bobodai/proj57_model",
    local_dir="output/train",
    resume_download=True,
)

print("下载完成")
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# 下载模型...
# Fetching 2 files:  50%|█████     | 1/2 [00:01<00:01,  1.55s/it]

# %%
# !pip install -q huggingface_hub

from huggingface_hub import snapshot_download

# 下载数据集
print("下载数据集...")
snapshot_download(
    "bobodai/proj57_dataset",
    repo_type="dataset",
    local_dir="output/dataset",
    resume_download=True,
)
print("下载完成")
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# 下载数据集...
# Fetching 677 files: 100%|██████████| 677/677 [01:42<00:00,  6.62it/s]
# 下载完成
